# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Juan González Hijon**
#
# Research Assistant

# %% [markdown]
# *I am interested in data science because I am a person who is curious about the search for patterns and conclusions in data.*

# %% [markdown]
# ### The next snippet is going to calculate the square root of 16

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %% [markdown]
# ---------------------------------------
